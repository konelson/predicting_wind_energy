# %%
pwd
# Out:
# '/Users/kelly/metis_v3/Project_2'

# %%
import pickle

# %%
with open('predicted_wind.pickle','rb') as read_file:
    predicted_wind = pickle.load(read_file)

# %%
predicted_wind.head()
# Out:
#      State  year  mw_year_0  mw_year_1  mw_year_2  mw_0_pred  mw_+1_pred  \
# 2  Alabama  2001        0.0        0.0        0.0  31.630484   31.630484
# 3  Alabama  2002        0.0        0.0        0.0  31.630484   31.630484
# 4  Alabama  2003        0.0        0.0        0.0  31.630484   31.630484
# 5  Alabama  2004        0.0        0.0        0.0  31.630484   31.630484
# 6  Alabama  2005        0.0        0.0        0.0  31.630484   31.630484
#
#    mw_+2_pred  mw_+3_pred
# 2   76.031333   126.93392
# 3   76.031333   126.93392
# 4   76.031333   126.93392
# 5   76.031333   126.93392
# 6   76.031333   126.93392

# %%
with open('state_area.pickle','rb') as read_file:
    state_area = pickle.load(read_file)

# %%
state_area
# Out:
# {'Alabama': '52,420',
#  'Alaska': '665,384',
#  'Arizona': '113,990',
#  'Arkansas': '53,179',
#  'California': '163,695',
#  'Colorado': '104,094',
#  'Connecticut': '5,543',
#  'Delaware': '2,489',
#  'District of Columbia': '68',
#  'Florida': '65,758',
#  'Georgia': '59,425',
#  'Hawaii': '10,932',
#  'Idaho': '83,569',
#  'Illinois': '57,914',
#  'Indiana': '36,420',
#  'Iowa': '56,273',
#  'Kansas': '82,278',
#  'Kentucky': '40,408',
#  'Louisiana': '52,378',
#  'Maine': '35,380',
#  'Maryland': '12,406',
#  'Massachusetts': '10,554',
#  'Michigan': '96,714',
#  'Minnesota': '86,936',
#  'Mississippi': '48,432',
#  'Missouri': '69,707',
#  'Montana': '147,040',
#  'Nebraska': '77,348',
#  'Nevada': '110,572',
#  'New Hampshire': '9,349',
#  'New Jersey': '8,723',
#  'New Mexico': '121,590',
#  'New York': '54,555',
#  'North Carolina': '53,819',
#  'North Dakota': '70,698',
#  'Ohio': '44,826',
#  'Oklahoma': '69,899',
#  'Oregon': '98,379',
#  'Pennsylvania': '46,054',
# ...

# %%
with open('median_income.pickle','rb') as read_file:
    median_income = pickle.load(read_file)

# %%
median_income.rename(columns = {'value':'median_income'})
# Out:
#          State  year  median_income
# 2      Alabama  2001        35160.0
# 3      Alabama  2002        37603.0
# 4      Alabama  2003        37255.0
# 5      Alabama  2004        36629.0
# 6      Alabama  2005        37150.0
# 7      Alabama  2006        37952.0
# 8      Alabama  2007        42212.0
# 9      Alabama  2008        44476.0
# 10     Alabama  2009        39980.0
# 11     Alabama  2010        40933.0
# 12     Alabama  2011        42590.0
# 13     Alabama  2012        43464.0
# 14     Alabama  2013        41381.0
# 15     Alabama  2014        42278.0
# 16     Alabama  2015        44509.0
# 17     Alabama  2016        47221.0
# 21      Alaska  2001        57363.0
# 22      Alaska  2002        52774.0
# 23      Alaska  2003        51837.0
# 24      Alaska  2004        55063.0
# 25      Alaska  2005        55891.0
# 26      Alaska  2006        56418.0
# 27      Alaska  2007        62993.0
# 28      Alaska  2008        63989.0
# 29      Alaska  2009        61604.0
# ...

# %%
with open('party_affiliation.pickle','rb') as read_file:
    state_parties = pickle.load(read_file)

# %%
state_parties
# Out:
# {'Alaska': {'Democratic': '116,454', 'Republican': '163,387'},
#  'Alabama': {'Democratic': '729,547', 'Republican': '1,318,255'},
#  'Arizona': {'Democratic': '1,161,167', 'Republican': '1,252,401'},
#  'Arkansas': {'Democratic': '380,494', 'Republican': '684,872'},
#  'California': {'Democratic': '8,753,788', 'Republican': '4,483,810'},
#  'Colorado': {'Democratic': '1,338,870', 'Republican': '1,202,484'},
#  'Connecticut': {'Democratic': '897,572', 'Republican': '673,215'},
#  'Delaware': {'Democratic': '235,603', 'Republican': '185,127'},
#  'Dist. of Col.': {'Democratic': '282,830', 'Republican': '12,723'},
#  'Florida': {'Democratic': '4,504,975 ', 'Republican': '4,617,886 '},
#  'Georgia': {'Democratic': '1,877,963', 'Republican': '2,089,104'},
#  'Hawaii': {'Democratic': '266,891', 'Republican': '128,847'},
#  'Idaho': {'Democratic': '189,765', 'Republican': '409,055'},
#  'Illinois': {'Democratic': '3,090,729', 'Republican': '2,146,015'},
# ...
